# %% [markdown]
# # xG features selection

# %% [markdown]
# We import pandas to travel into shots

# %%
import pandas as pd

# %% [markdown]
# We configure matplolib display

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
data_folder = '/home/dam/www/saf/data/stats/expg/expg_prepared_data/engineered'

# %%
start = 2012
end = 2017
shots = pd.DataFrame()
for year in xrange(start, end, 1):
    data = pd.read_csv(data_folder+'/'+str(year)+'.csv')
    shots = pd.concat([shots, data])

# %% [markdown]
# ## Shot distance

# %%
nb_shots_by_distance = shots.groupby(shots['distance'].apply(lambda x: round(x, 0))).agg(['count'])['start']
nb_shots_by_distance.plot.bar()
plt.xlim(0, 60)
# Out:
# (0, 60)

# %% [markdown]
# ## Shot angle

# %%
nb_shots_by_angle = shots.groupby(shots['degree'].apply(lambda x: round(x, 0))).agg(['count'])['start']
nb_shots_by_angle.plot.bar()
plt.xlim(0, 90)
# Out:
# (0, 90)

# %% [markdown]
# ## Last pass distance

# %%
nb_shots_by_angle = shots.groupby(shots['pass_distance'].apply(lambda x: round(x, 0))).agg(['count'])['start']
nb_shots_by_angle.plot.bar()
plt.xlim(0, 80)
# Out:
# (0, 80)

# %% [markdown]
# ## Attack speed

# %%
nb_shots_by_angle = shots.groupby(shots['attack_speed'].apply(lambda x: round(x, 0))).agg(['count'])['start']
nb_shots_by_angle.plot.bar()
plt.xlim(0, 50)
# Out:
# (0, 50)
